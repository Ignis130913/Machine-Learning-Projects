# %%
import pandas as pd
import numpy as np
data1=pd.read_csv('/content/customer_data[1].csv')
data2=pd.read_csv('/content/payment_data.csv')
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)

# %%
data=pd.merge(data1,data2)
safe_data=data
safe_data
# Out:
#       label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0         1  54982665      5  1245.5      3   77000.0      2     15      5
# 1         1  54982665      5  1245.5      3   77000.0      2     15      5
# 2         1  54982665      5  1245.5      3   77000.0      2     15      5
# 3         1  54982665      5  1245.5      3   77000.0      2     15      5
# 4         0  59004779      4  1277.0      1  113000.0      2      8     -1
# ...     ...       ...    ...     ...    ...       ...    ...    ...    ...
# 8245      0  58998054      4  1250.0      3  137000.0      2      8      5
# 8246      0  58998054      4  1250.0      3  137000.0      2      8      5
# 8247      0  54989781      4  1415.0      3   93000.0      2      8      5
# 8248      0  54989781      4  1415.0      3   93000.0      2      8      5
# 8249      0  54989781      4  1415.0      3   93000.0      2      8      5
#
# ...

# %%
data.head(10)
# Out:
#    label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0      1  54982665      5  1245.5      3   77000.0      2     15      5
# 1      1  54982665      5  1245.5      3   77000.0      2     15      5
# 2      1  54982665      5  1245.5      3   77000.0      2     15      5
# 3      1  54982665      5  1245.5      3   77000.0      2     15      5
# 4      0  59004779      4  1277.0      1  113000.0      2      8     -1
# 5      0  59004779      4  1277.0      1  113000.0      2      8     -1
# 6      0  59004779      4  1277.0      1  113000.0      2      8     -1
# 7      0  59004779      4  1277.0      1  113000.0      2      8     -1
# 8      0  59004779      4  1277.0      1  113000.0      2      8     -1
# 9      0  59004779      4  1277.0      1  113000.0      2      8     -1
#
#    fea_8  fea_9  fea_10      fea_11  OVD_t1  OVD_t2  OVD_t3  OVD_sum  \
# 0    109      5  151300  244.948974       0       0       0        0
# ...

# %%
data.columns
# Out:
# Index(['label', 'id', 'fea_1', 'fea_2', 'fea_3', 'fea_4', 'fea_5', 'fea_6',
#        'fea_7', 'fea_8', 'fea_9', 'fea_10', 'fea_11', 'OVD_t1', 'OVD_t2',
#        'OVD_t3', 'OVD_sum', 'pay_normal', 'prod_code', 'prod_limit',
#        'update_date', 'new_balance', 'highest_balance', 'report_date'],
#       dtype='object')

# %%
data.isnull().sum()/data.shape[0]*100
# Out:
# label               0.000000
# id                  0.000000
# fea_1               0.000000
# fea_2              12.460606
# fea_3               0.000000
# fea_4               0.000000
# fea_5               0.000000
# fea_6               0.000000
# fea_7               0.000000
# fea_8               0.000000
# fea_9               0.000000
# fea_10              0.000000
# fea_11              0.000000
# OVD_t1              0.000000
# OVD_t2              0.000000
# OVD_t3              0.000000
# OVD_sum             0.000000
# pay_normal          0.000000
# prod_code           0.000000
# prod_limit         74.157576
# update_date         0.315152
# new_balance         0.000000
# highest_balance     4.957576
# report_date        13.503030
# dtype: float64

# %%
data.dtypes
# Out:
# label                int64
# id                   int64
# fea_1                int64
# fea_2              float64
# fea_3                int64
# fea_4              float64
# fea_5                int64
# fea_6                int64
# fea_7                int64
# fea_8                int64
# fea_9                int64
# fea_10               int64
# fea_11             float64
# OVD_t1               int64
# OVD_t2               int64
# OVD_t3               int64
# OVD_sum              int64
# pay_normal           int64
# prod_code            int64
# prod_limit         float64
# update_date         object
# new_balance        float64
# highest_balance    float64
# report_date         object
# dtype: object

# %%
data['report_date']=pd.to_datetime(data['report_date'])
# Out:
# <ipython-input-8-6ba9d6861fee>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['report_date']=pd.to_datetime(data['report_date'])

# %%
data.head(2)
# Out:
#    label        id  fea_1   fea_2  fea_3    fea_4  fea_5  fea_6  fea_7  fea_8  \
# 0      1  54982665      5  1245.5      3  77000.0      2     15      5    109
# 1      1  54982665      5  1245.5      3  77000.0      2     15      5    109
#
#    fea_9  fea_10      fea_11  OVD_t1  OVD_t2  OVD_t3  OVD_sum  pay_normal  \
# 0      5  151300  244.948974       0       0       0        0           9
# 1      5  151300  244.948974       0       0       0        0          18
#
#    prod_code  prod_limit update_date  new_balance  highest_balance report_date
# 0         10     60500.0  31/01/2015       6657.6          18934.0  2015-09-19
# 1         10         NaN  28/04/2009     153792.0         149387.0  2015-10-08

# %%
data['update_date']=pd.to_datetime(data['update_date'])
# Out:
# <ipython-input-10-ee2fbb3c3c3a>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['update_date']=pd.to_datetime(data['update_date'])

# %%
data.columns
# Out:
# Index(['label', 'id', 'fea_1', 'fea_2', 'fea_3', 'fea_4', 'fea_5', 'fea_6',
#        'fea_7', 'fea_8', 'fea_9', 'fea_10', 'fea_11', 'OVD_t1', 'OVD_t2',
#        'OVD_t3', 'OVD_sum', 'pay_normal', 'prod_code', 'prod_limit',
#        'update_date', 'new_balance', 'highest_balance', 'report_date'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# label                 0
# id                    0
# fea_1                 0
# fea_2              1028
# fea_3                 0
# fea_4                 0
# fea_5                 0
# fea_6                 0
# fea_7                 0
# fea_8                 0
# fea_9                 0
# fea_10                0
# fea_11                0
# OVD_t1                0
# OVD_t2                0
# OVD_t3                0
# OVD_sum               0
# pay_normal            0
# prod_code             0
# prod_limit         6118
# update_date          26
# new_balance           0
# highest_balance     409
# report_date        1114
# dtype: int64

# %%
data['highest_balance']=data['highest_balance'].fillna(data['highest_balance'].mean(skipna=True))
data['fea_2']=data['fea_2'].fillna(data['fea_2'].mean(skipna=True))

# %%
data['report_date']=data['report_date'].fillna(data['report_date'].mean(skipna=True))
data['update_date']=data['update_date'].fillna(data['update_date'].mean(skipna=True))
data['prod_limit']=data['prod_limit'].fillna(data['prod_limit'].mean(skipna=True))

# %%
del data['id']

# %%
data.isnull().sum()
# Out:
# label              0
# fea_1              0
# fea_2              0
# fea_3              0
# fea_4              0
# fea_5              0
# fea_6              0
# fea_7              0
# fea_8              0
# fea_9              0
# fea_10             0
# fea_11             0
# OVD_t1             0
# OVD_t2             0
# OVD_t3             0
# OVD_sum            0
# pay_normal         0
# prod_code          0
# prod_limit         0
# update_date        0
# new_balance        0
# highest_balance    0
# report_date        0
# dtype: int64

# %%
matrix=data[['label','fea_10']].corr()
matrix
# Out:
#            label    fea_10
# label   1.000000 -0.019135
# fea_10 -0.019135  1.000000

# %%
data.columns
# Out:
# Index(['label', 'fea_1', 'fea_2', 'fea_3', 'fea_4', 'fea_5', 'fea_6', 'fea_7',
#        'fea_8', 'fea_9', 'fea_10', 'fea_11', 'OVD_t1', 'OVD_t2', 'OVD_t3',
#        'OVD_sum', 'pay_normal', 'prod_code', 'prod_limit', 'update_date',
#        'new_balance', 'highest_balance', 'report_date'],
#       dtype='object')

# %%
data['sum_fea']=data['fea_1'] + data['fea_2'] + data['fea_3'] + data['fea_4'] + data['fea_5']+data['fea_6']+data['fea_7'] + data['fea_8']+ data['fea_9']+data['fea_10']+ data['fea_11']

# %%
data['sum_fea']
# Out:
# 0       229934.448974
# 1       229934.448974
# 2       229934.448974
# 3       229934.448974
# 4       456360.173840
#             ...
# 8245    210368.000000
# 8246    210368.000000
# 8247    246127.861279
# 8248    246127.861279
# 8249    246127.861279
# Name: sum_fea, Length: 8250, dtype: float64

# %%
data["date_freq"]=(data["report_date"]-data["update_date"] )/ np.timedelta64(1,'D')

# %%
matrix=data.corr()
matrix
# Out:
# <ipython-input-25-884cca7e2ddd>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix=data.corr()
#                     label     fea_1     fea_2     fea_3     fea_4     fea_5  \
# label            1.000000  0.032233 -0.051257  0.049188 -0.152145  0.022042
# fea_1            0.032233  1.000000 -0.001116  0.002138 -0.135093 -0.022554
# fea_2           -0.051257 -0.001116  1.000000 -0.226838  0.253737  0.011534
# fea_3            0.049188  0.002138 -0.226838  1.000000 -0.093287 -0.018539
# fea_4           -0.152145 -0.135093  0.253737 -0.093287  1.000000  0.051830
# fea_5            0.022042 -0.022554  0.011534 -0.018539  0.051830  1.000000
# fea_6            0.054692  0.319891 -0.014838  0.159807 -0.188123  0.031045
# fea_7           -0.012302  0.013758  0.013341  0.275816 -0.072641 -0.012207
# ...

# %%
data.columns
# Out:
# Index(['label', 'fea_1', 'fea_2', 'fea_3', 'fea_4', 'fea_5', 'fea_6', 'fea_7',
#        'fea_8', 'fea_9', 'fea_10', 'fea_11', 'OVD_t1', 'OVD_t2', 'OVD_t3',
#        'OVD_sum', 'pay_normal', 'prod_code', 'prod_limit', 'update_date',
#        'new_balance', 'highest_balance', 'report_date', 'sum_fea',
#        'date_freq'],
#       dtype='object')

# %%
set_data=data[['label','OVD_t1', 'OVD_t2', 'OVD_t3',
       'OVD_sum', 'pay_normal', 'prod_code', 'prod_limit', 'update_date',
       'new_balance', 'highest_balance', 'report_date', 'sum_fea']]
data=set_data

# %%
data.columns
# Out:
# Index(['label', 'OVD_t1', 'OVD_t2', 'OVD_t3', 'OVD_sum', 'pay_normal',
#        'prod_code', 'prod_limit', 'update_date', 'new_balance',
#        'highest_balance', 'report_date', 'sum_fea'],
#       dtype='object')

# %%
data['ovd_mean']=data['OVD_t1']+data['OVD_t2']+data['OVD_t3']/3
# Out:
# <ipython-input-33-81e899111322>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ovd_mean']=data['OVD_t1']+data['OVD_t2']+data['OVD_t3']/3

# %%
del data['OVD_t1']
del data['OVD_t2']
del data['OVD_t3']

# %%
data.columns
# Out:
# Index(['label', 'OVD_sum', 'pay_normal', 'prod_code', 'prod_limit',
#        'update_date', 'new_balance', 'highest_balance', 'report_date',
#        'sum_fea', 'ovd_mean'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(data=data,x='label',y='highest_balance')
# Out:
# <Axes: xlabel='label', ylabel='highest_balance'>

# %%
matrix=data.corr()
sns.heatmap(matrix)
# Out:
# <ipython-input-37-c6d4f3aa7919>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix=data.corr()
# <Axes: >

# %%
y=data['label']

# %%
del data['label']
del data['report_date']
del data['update_date']

# %%
x=data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)
model=LogisticRegression()

# %%
x_train.ndim
# Out:
# 2

# %%
y_train.ndim
# Out:
# 1

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
predict=model.predict(x_test)
accuracy_score(y_test,predict)
# Out:
# 0.8309090909090909

# %%
from sklearn.ensemble import RandomForestClassifier
tree=RandomForestClassifier()
tree.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
prediction=tree.predict(x_test)
accuracy_score(y_test,prediction)
# Out:
# 0.8436363636363636

# %%
prediction

# %%
from sklearn.metrics import classification_report
import xgboost as xgb
xgb_classifier = xgb.XGBClassifier()
xgb_classifier.fit(x_train, y_train)
y_pred = xgb_classifier.predict(x_test)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      1370
#            1       0.91      0.57      0.70       280
#
#     accuracy                           0.92      1650
#    macro avg       0.91      0.78      0.83      1650
# weighted avg       0.92      0.92      0.91      1650

# %%
pred2= xgb_classifier.predict(x_test)
accuracy_score(y_test, pred2)
# Out:
# 0.9175757575757576

# %%
data['ovd_mean'].value_counts()
# Out:
# 0.000000     7330
# 1.000000      301
# 2.000000      118
# 3.000000       75
# 4.000000       53
# 5.000000       34
# 8.000000       25
# 7.000000       24
# 6.000000       22
# 9.000000       21
# 11.666667      17
# 11.333333      13
# 0.333333       10
# 4.333333       10
# 5.333333       10
# 12.000000       9
# 4.666667        8
# 3.666667        8
# 11.000000       8
# 10.666667       7
# 0.666667        7
# 6.333333        7
# 13.000000       6
# 6.666667        6
# 16.000000       6
# 7.333333        6
# 3.333333        5
# 15.000000       5
# 3.666667        5
# 12.333333       5
# 7.666667        4
# 14.000000       4
# 1.333333        4
# 17.000000       4
# 8.333333        4
# 8.666667        4
# 10.333333       3
# 34.000000       3
# 10.666667       3
# 9.666667        3
# 14.333333       2
# 1.666667        2
# 18.000000       2
# 19.000000       2
# 10.000000       2
# 2.666667        2
# 12.666667       2
# 9.333333        2
# 13.333333       2
# 5.333333        2
# ...

# %%
del data['prod_code']
data.head(10)
# Out:
#    OVD_sum  pay_normal  new_balance  highest_balance        sum_fea  \
# 0        0           9       6657.6          18934.0  229934.448974
# 1        0          18     153792.0         149387.0  229934.448974
# 2        0           1          0.0         150500.0  229934.448974
# 3    11906           6          0.0          46371.0  229934.448974
# 4        0           4      15120.0          21500.0  456360.173840
# 5        0           5       5596.8          14500.0  456360.173840
# 6        0           5       8257.2          13119.0  456360.173840
# 7        0          12          0.0          66701.0  456360.173840
# 8        0          28       1633.2          29993.0  456360.173840
# 9        0           8          0.0          41000.0  456360.173840
#
#     ovd_mean  label
# 0   0.000000      1
# 1   0.000000      1
# 2   0.000000      1
# 3  10.666667      1
# 4   0.000000      0
# 5   0.000000      0
# 6   0.000000      0
# 7   0.000000      0
# 8   0.000000      0
# ...

# %%
data['fea_1'].value_counts()
# Out:
# 7    3581
# 4    2520
# 5    2054
# 1      73
# 2      15
# 6       7
# Name: fea_1, dtype: int64

# %%
x.columns
# Out:
# Index(['OVD_sum', 'pay_normal', 'prod_code', 'prod_limit', 'new_balance',
#        'highest_balance', 'sum_fea', 'ovd_mean'],
#       dtype='object')

# %%
data['label']=safe_data['label']
# Out:
# <ipython-input-75-5d64aeb6cc95>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['label']=safe_data['label']

# %%
matrix=data.corr()
matrix
# Out:
#                   OVD_sum  pay_normal  prod_code  new_balance  \
# OVD_sum          1.000000   -0.091390   0.020237    -0.005612
# pay_normal      -0.091390    1.000000   0.091917     0.001840
# prod_code        0.020237    0.091917   1.000000    -0.075127
# new_balance     -0.005612    0.001840  -0.075127     1.000000
# highest_balance -0.005153   -0.003425  -0.012221     0.751544
# sum_fea          0.036442    0.040160   0.027069     0.009366
# ovd_mean         0.494370   -0.027801   0.006546    -0.008785
# label            0.045156   -0.061594  -0.018054     0.035648
#
#                  highest_balance   sum_fea  ovd_mean     label
# OVD_sum                -0.005153  0.036442  0.494370  0.045156
# pay_normal             -0.003425  0.040160 -0.027801 -0.061594
# prod_code              -0.012221  0.027069  0.006546 -0.018054
# new_balance             0.751544  0.009366 -0.008785  0.035648
# highest_balance         1.000000  0.017802  0.010356  0.054952
# ...

# %%
x_new_train=x_train[['OVD_sum', 'pay_normal','new_balance',
       'highest_balance', 'sum_fea', 'ovd_mean']]
x_new_test=x_test[['OVD_sum', 'pay_normal','new_balance',
       'highest_balance', 'sum_fea', 'ovd_mean']]
model2=xgb.XGBClassifier()
model2.fit(x_new_train, y_train)
y_pred_new = model2.predict(x_new_test)

# %%
accuracy_score(y_test,y_pred_new)
# Out:
# 0.923030303030303

# %%
input_values = np.array(['0','9','6657.6','18934.0','229934.448974','0.0'], dtype=np.float32).reshape(1, 6)
predicted_class =model2.predict(input_values)
if predicted_class == 0:
    print("No Loan")
else:
    print("Loan")
# Out:
# Loan

# %%
accuracy_score(y_test,y_pred_new)
# Out:
# 0.923030303030303
